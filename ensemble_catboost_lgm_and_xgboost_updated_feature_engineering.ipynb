# %% [markdown]
# <a href="https://www.kaggle.com/code/vedikagupta0/catboost-lgbm-xgb-churn-prediction-0-912?scriptVersionId=305518483" target="_blank"><img align="left" alt="Kaggle" title="Open in Kaggle" src="https://kaggle.com/static/images/open-in-kaggle.svg"></a>

# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import math
from catboost import CatBoostClassifier
import lightgbm as lgb
from xgboost import XGBClassifier
from sklearn.model_selection import StratifiedKFold
from sklearn.preprocessing import MinMaxScaler
from sklearn.metrics import accuracy_score, f1_score, roc_auc_score
from sklearn.metrics import (
    classification_report,
    confusion_matrix,
    roc_auc_score,
    roc_curve,
    precision_recall_curve,
    f1_score,
    accuracy_score
)
from sklearn.model_selection import train_test_split
from sklearn.utils import resample
from sklearn.preprocessing import LabelEncoder
df_og = pd.read_csv('/kaggle/input/competitions/playground-series-s6e3/train.csv')
df2 = pd.read_csv('https://raw.githubusercontent.com/IBM/telco-customer-churn-on-icp4d/master/data/Telco-Customer-Churn.csv')
tf = pd.read_csv('/kaggle/input/competitions/playground-series-s6e3/test.csv')

# %%
df_og.head()
# Out:
#    id  gender  SeniorCitizen Partner Dependents  tenure PhoneService  \
# 0   0    Male              0     Yes        Yes      29          Yes
# 1   1    Male              0     Yes        Yes      58          Yes
# 2   2    Male              0     Yes         No      58          Yes
# 3   3  Female              0      No         No       1          Yes
# 4   4  Female              0      No         No       1          Yes
#
#   MultipleLines InternetService OnlineSecurity  ... DeviceProtection  \
# 0            No             DSL            Yes  ...              Yes
# 1            No             DSL            Yes  ...               No
# 2           Yes     Fiber optic             No  ...               No
# 3            No     Fiber optic             No  ...               No
# 4            No     Fiber optic             No  ...               No
#
#   TechSupport StreamingTV StreamingMovies        Contract PaperlessBilling  \
# 0         Yes          No              No        One year              Yes
# 1         Yes         Yes              No        Two year               No
# 2          No         Yes             Yes  Month-to-month              Yes
# 3          No          No              No  Month-to-month              Yes
# 4          No          No              No  Month-to-month              Yes
#
#              PaymentMethod MonthlyCharges  TotalCharges  Churn
# 0             Mailed check          60.10       1653.85     No
# 1  Credit card (automatic)          69.50       3778.20     No
# 2         Electronic check         100.40       5841.35     No
# 3         Electronic check          69.70         70.70    Yes
# 4         Electronic check          70.45         70.45    Yes
#
# [5 rows x 21 columns]

# %%
df2.head()
# Out:
#    customerID  gender  SeniorCitizen Partner Dependents  tenure PhoneService  \
# 0  7590-VHVEG  Female              0     Yes         No       1           No
# 1  5575-GNVDE    Male              0      No         No      34          Yes
# 2  3668-QPYBK    Male              0      No         No       2          Yes
# 3  7795-CFOCW    Male              0      No         No      45           No
# 4  9237-HQITU  Female              0      No         No       2          Yes
#
#       MultipleLines InternetService OnlineSecurity  ... DeviceProtection  \
# 0  No phone service             DSL             No  ...               No
# 1                No             DSL            Yes  ...              Yes
# 2                No             DSL            Yes  ...               No
# 3  No phone service             DSL            Yes  ...              Yes
# 4                No     Fiber optic             No  ...               No
#
#   TechSupport StreamingTV StreamingMovies        Contract PaperlessBilling  \
# 0          No          No              No  Month-to-month              Yes
# 1          No          No              No        One year               No
# 2          No          No              No  Month-to-month              Yes
# 3         Yes          No              No        One year               No
# 4          No          No              No  Month-to-month              Yes
#
#                PaymentMethod MonthlyCharges  TotalCharges Churn
# 0           Electronic check          29.85         29.85    No
# 1               Mailed check          56.95        1889.5    No
# 2               Mailed check          53.85        108.15   Yes
# 3  Bank transfer (automatic)          42.30       1840.75    No
# 4           Electronic check          70.70        151.65   Yes
#
# [5 rows x 21 columns]

# %%
id_col = ['id', 'customerID']

# %%
df_og.describe(include='object')
# Out:
#         gender Partner Dependents PhoneService MultipleLines InternetService  \
# count   594194  594194     594194       594194        594194          594194
# unique       2       2          2            2             3               3
# top     Female     Yes         No          Yes            No     Fiber optic
# freq    298738  309554     414362       557893        283384          272386
#
#        OnlineSecurity OnlineBackup DeviceProtection TechSupport StreamingTV  \
# count          594194       594194           594194      594194      594194
# unique              3            3                3           3           3
# top                No           No               No          No         Yes
# freq           289474       250083           247377      288571      240301
#
#        StreamingMovies        Contract PaperlessBilling     PaymentMethod  \
# count           594194          594194           594194            594194
# unique               3               3                2                 4
# top                Yes  Month-to-month              Yes  Electronic check
# freq            241435          298918           365579            215372
#
#          Churn
# count   594194
# unique       2
# top         No
# freq    460377

# %%
df2.describe(include='object')
# Out:
#         customerID gender Partner Dependents PhoneService MultipleLines  \
# count         7043   7043    7043       7043         7043          7043
# unique        7043      2       2          2            2             3
# top     3186-AJIEK   Male      No         No          Yes            No
# freq             1   3555    3641       4933         6361          3390
#
#        InternetService OnlineSecurity OnlineBackup DeviceProtection  \
# count             7043           7043         7043             7043
# unique               3              3            3                3
# top        Fiber optic             No           No               No
# freq              3096           3498         3088             3095
#
#        TechSupport StreamingTV StreamingMovies        Contract  \
# count         7043        7043            7043            7043
# unique           3           3               3               3
# top             No          No              No  Month-to-month
# freq          3473        2810            2785            3875
#
#        PaperlessBilling     PaymentMethod TotalCharges Churn
# count              7043              7043         7043  7043
# unique                2                 4         6531     2
# top                 Yes  Electronic check                 No
# freq               4171              2365           11  5174

# %% [markdown]
# ##### no null values were observed

# %%
df2.shape
# Out:
# (7043, 21)

# %%
df_og.shape
# Out:
# (594194, 21)

# %%
df = pd.concat([df_og, df2], axis=0)

# %%
df.drop(columns=id_col, inplace=True)

# %%
df.shape
# Out:
# (601237, 20)

# %% [markdown]
# ### mapped senior citizen to general binary format following the dataset format.

# %%
df['SeniorCitizen'] = df['SeniorCitizen'].map({0:'No', 1:'Yes'})
df_og['SeniorCitizen'] = df_og['SeniorCitizen'].map({0:'No', 1:'Yes'})
tf['SeniorCitizen'] = tf['SeniorCitizen'].map({0:'No', 1:'Yes'})

# %% [markdown]
# ### since less cardinality exists, we can have a look at the unique values each feature possess.

# %%
for col in df.columns:
    print(f"{col} --> {df[col].unique()}")
    print()
# Out:
# gender --> ['Male' 'Female']
#
# SeniorCitizen --> ['No' 'Yes']
#
# Partner --> ['Yes' 'No']
#
# Dependents --> ['Yes' 'No']
#
# tenure --> [29 58  1 24 72 55 13 67 33 63  3 31 27 52 68 35 66 17 59 61 12 37 64 23
#   9  8 15 18 19 51  5 71 60 62 45 69 40 53 54 34  2 70 39 41  4 22 46 28
#  42 48 21 43 14 10 47  7 57 36 16 26 20 50 30 11 44 25 56  6 65 38 49 32
#   0]
#
# PhoneService --> ['Yes' 'No']
#
# MultipleLines --> ['No' 'Yes' 'No phone service']
#
# InternetService --> ['DSL' 'Fiber optic' 'No']
#
# OnlineSecurity --> ['Yes' 'No' 'No internet service']
#
# OnlineBackup --> ['No' 'Yes' 'No internet service']
#
# DeviceProtection --> ['Yes' 'No' 'No internet service']
#
# TechSupport --> ['Yes' 'No' 'No internet service']
#
# StreamingTV --> ['No' 'Yes' 'No internet service']
#
# StreamingMovies --> ['No' 'Yes' 'No internet service']
#
# Contract --> ['One year' 'Two year' 'Month-to-month']
#
# PaperlessBilling --> ['Yes' 'No']
#
# PaymentMethod --> ['Mailed check' 'Credit card (automatic)' 'Electronic check'
#  'Bank transfer (automatic)']
#
# MonthlyCharges --> [ 60.1   69.5  100.4  ...  46.15  18.4   37.7 ]
#
# TotalCharges --> [1653.85 3778.2 5841.35 ... '346.45' '306.6' '6844.5']
#
# Churn --> ['No' 'Yes']

# %%
df['TotalCharges'] = df['TotalCharges'].replace(' ',0).astype(float)
df['is_auto_payment'] = df['PaymentMethod'].str.contains('automatic').astype(int)
df['paperless_autopay'] = ((df['PaperlessBilling'] == 'Yes') & (df['is_auto_payment'] == 1)).astype(int)

df['high_monthlycharges'] = (df['MonthlyCharges'] > df['MonthlyCharges'].mean()).astype(int)
df['high_totalcharges'] = (df['TotalCharges'] > df['TotalCharges'].mean()).astype(int)

tenure_75 = df['tenure'].quantile(0.75)
df['high_tenure'] = (df['tenure'] > tenure_75).astype(int)

df['is_male_senior'] = ((df['gender'] == 'Male') & (df['SeniorCitizen'] == 'Yes')).astype(int)

def feature_streaming_internet_phone_all_true(df):
    return (
        (df['StreamingTV'] == 'Yes') &
        (df['StreamingMovies'] == 'Yes') &
        (df['InternetService'].isin(['DSL', 'Fiber optic'])) &
        (df['PhoneService'] == 'Yes')
    ).astype(int)


def feature_support_bundle_all_true(df):
    return (
        (df['DeviceProtection'] == 'Yes') &
        (df['OnlineBackup'] == 'Yes') &
        (df['OnlineSecurity'] == 'Yes') &
        (df['TechSupport'] == 'Yes')
    ).astype(int)

df['feat_streaming_internet_phone'] = feature_streaming_internet_phone_all_true(df)
df['feat_support_bundle'] = feature_support_bundle_all_true(df)

# %%
tf['TotalCharges'] = tf['TotalCharges'].replace('',0).astype(float)
tf['is_auto_payment'] = tf['PaymentMethod'].str.contains('automatic').astype(int)
tf['paperless_autopay'] = ((tf['PaperlessBilling'] == 'Yes') & (tf['is_auto_payment'] == 1)).astype(int)

tf['high_monthlycharges'] = (tf['MonthlyCharges'] > tf['MonthlyCharges'].mean()).astype(int)
tf['high_totalcharges'] = (tf['TotalCharges'] > tf['TotalCharges'].mean()).astype(int)

tenure_75 = tf['tenure'].quantile(0.75)
tf['high_tenure'] = (tf['tenure'] > tenure_75).astype(int)

tf['is_male_senior'] = ((tf['gender'] == 'Male') & (tf['SeniorCitizen'] == 'Yes')).astype(int)

tf['feat_streaming_internet_phone'] = feature_streaming_internet_phone_all_true(tf)
tf['feat_support_bundle'] = feature_support_bundle_all_true(tf)

# %% [markdown]
# ### categorized columns into binary columns, trinary columns, numerical columns and other columns.

# %%
bin_cols = ['SeniorCitizen', 'Partner', 'Dependents', 'PhoneService', 'PaperlessBilling']
trinary_cols = [
    "MultipleLines",
    "OnlineSecurity",
    "OnlineBackup",
    "DeviceProtection",
    "TechSupport",
    "StreamingTV",
    "StreamingMovies"
]
combined_cols = bin_cols + trinary_cols
other_cols = ['InternetService', 'Contract', 'PaymentMethod']
num_cols =['tenure', 'TotalCharges', 'MonthlyCharges']

# %%
df[num_cols] = df[num_cols].replace(' ', 0).astype(float)
for col1 in num_cols:
    for col2 in num_cols:
        if col1!=col2:   
            df[f'{col1}_{col2}_ratio'] = df[col1]/df[col2]
            df_og[f'{col1}_{col2}_ratio'] = df_og[col1]/df_og[col2]
            tf[f'{col1}_{col2}_ratio'] = tf[col1]/tf[col2]

# %%
df['all_binary_same'] = df[bin_cols].nunique(axis=1) == 1
tf['all_binary_same'] = tf[bin_cols].nunique(axis=1) == 1
df_og['all_binary_same'] = df_og[bin_cols].nunique(axis=1) == 1
df['all_trinary_same'] = df[trinary_cols].nunique(axis=1) == 1
df_og['all_trinary_same'] = df_og[trinary_cols].nunique(axis=1) == 1
tf['all_trinary_same'] = tf[trinary_cols].nunique(axis=1) == 1
df['all_same_services'] = df[combined_cols].nunique(axis=1) == 1
df_og['all_same_services'] = df_og[combined_cols].nunique(axis=1) == 1
tf['all_same_services'] = tf[combined_cols].nunique(axis=1) == 1

# %%
df['all_same_services'].value_counts()
# Out:
# all_same_services
# False    601068
# True        169
# Name: count, dtype: int64

# %%
df = df.reset_index(drop=True)

# %%
fig, axes = plt.subplots(1, 3, figsize=(18, 5))

for i, col in enumerate(num_cols):
    sns.boxplot(
        x="InternetService",
        y=col,
        data=df,
        ax=axes[i]
    )
    axes[i].set_title(f"{col} vs InternetService")

plt.tight_layout()
plt.show()

# %%
for col in num_cols:
    df[f'categorical_{col}'] = df[col].astype(str)
    df_og[f'categorical_{col}'] = df_og[col].astype(str)
    tf[f'categorical_{col}'] = tf[col].astype(str)

# %%
df['Churn'] = df['Churn'].map({'No':0, 'Yes':1})
df_og['Churn'] = df_og['Churn'].map({'No':0, 'Yes':1})

# %%
cols = ['StreamingMovies', 'StreamingTV', 'TechSupport',
        'DeviceProtection', 'OnlineBackup', 'OnlineSecurity']

mask = (df[cols] == 'No internet service').all(axis=1)
filtered_df = df[mask]
filtered_df.shape
# Out:
# (142253, 40)

# %%
no_int= 100 - ((df.shape[0] - 140727)/ df.shape[0])*100
print(f'{round(no_int,2)}% is having no internet service in {cols}')
# Out:
# 23.41% is having no internet service in ['StreamingMovies', 'StreamingTV', 'TechSupport', 'DeviceProtection', 'OnlineBackup', 'OnlineSecurity']

# %%
dup = df.duplicated().sum()
print(f'{round(dup,3)} duplicate values exist in our df.')
# Out:
# 22 duplicate values exist in our df.

# %% [markdown]
# #### removed duplicate values
# #### added dominance of no internet service, same binary, trinary, same servicess, fixed contract time, automatic payment

# %%
df.drop_duplicates(inplace=True)

# %%
df['dominance_of_nointernetservice'] = (df[cols] == 'No internet service').all(axis=1)
df_og['dominance_of_nointernetservice'] = (df_og[cols] == 'No internet service').all(axis=1)
tf['dominance_of_nointernetservice'] = (tf[cols] == 'No internet service').all(axis=1)

# %%
df.dominance_of_nointernetservice.value_counts()
# Out:
# dominance_of_nointernetservice
# False    458976
# True     142239
# Name: count, dtype: int64

# %%
df['is_fixed_contract_time'] = df['Contract'].apply(lambda x : True if 'year' in x else False)
df_og['is_fixed_contract_time'] = df_og['Contract'].apply(lambda x : True if 'year' in x else False)
tf['is_fixed_contract_time'] = tf['Contract'].apply(lambda x : True if 'year' in x else False)
df['is_automatic_payment'] = df['PaymentMethod'].apply(lambda x : True if 'automatic' in x else False)
df_og['is_automatic_payment'] = df_og['PaymentMethod'].apply(lambda x : True if 'automatic' in x else False)
tf['is_automatic_payment'] = tf['PaymentMethod'].apply(lambda x : True if 'automatic' in x else False)

# %%
# n = len(df.columns)
# ncols = 3
# nrows = math.ceil(n / ncols)

# # violin plots in grid
# fig, axes = plt.subplots(nrows, ncols, figsize=(5*ncols, 4*nrows))
# axes = axes.flatten()

# for i, col in enumerate(df.columns):
#     sns.violinplot(y=df[col], ax=axes[i])
#     axes[i].set_title(col)

# # remove empty axes
# for j in range(i+1, len(axes)):
#     fig.delaxes(axes[j])

# plt.tight_layout()
# plt.show()

# %%
pattern_map = {
    "SeniorCitizen": 'Yes',
    "Dependents": 'Yes',
    "PhoneService": 'No',
    "PaperlessBilling": 'No',
    "all_trinary_same": 1,
    "all_binary_same": 1,
    "dominance_of_nointernetservice": 1
}
df['rarity_factor'] = sum(
    (df[col] == val).astype(int)
    for col, val in pattern_map.items()
)

df_og['rarity_factor'] = sum(
    (df_og[col] == val).astype(int)
    for col, val in pattern_map.items()
)

tf['rarity_factor'] = sum(
    (tf[col] == val).astype(int)
    for col, val in pattern_map.items()
)
n = len(pattern_map)

df['rarity_factor'] = 5 * df['rarity_factor'] / n
df_og['rarity_factor'] = 5 * df_og['rarity_factor'] / n
tf['rarity_factor'] = 5 * tf['rarity_factor'] / n

# %%
df_0 = df[df['Churn'] == 0]
df_1 = df[df['Churn'] == 1]

df_0_down = resample(
    df_0,
    replace=False,
    n_samples=150000,
    random_state=42
)

df = pd.concat([df_0_down, df_1])
df = df.sample(frac=1, random_state=42).reset_index(drop=True)
print(f"downsampled 'No Churn' to 1.5M!")
df.Churn.value_counts()
# Out:
# downsampled 'No Churn' to 1.5M!
# Churn
# 0    150000
# 1    135674
# Name: count, dtype: int64

# %%
cols=['gender', 'SeniorCitizen', 'Partner', 'Dependents',        'PhoneService', 'MultipleLines', 'InternetService', 'OnlineSecurity',
       'OnlineBackup', 'DeviceProtection', 'TechSupport', 'StreamingTV',
       'StreamingMovies', 'Contract', 'PaperlessBilling', 'PaymentMethod',
'all_binary_same',
       'all_trinary_same', 'all_same_services',
       'dominance_of_nointernetservice', 'is_fixed_contract_time',
       'is_automatic_payment', 'rarity_factor', 'categorical_tenure', 'categorical_MonthlyCharges', 'categorical_TotalCharges']

# %%
encodings = {}

target = "Churn"

for col in cols:
    mapping = df.groupby(col)[target].mean()
    encodings[col] = mapping

    print(f"{col} target encoding:")
    print(mapping.to_dict())
    print("-" * 40)

for col in cols:
    df[col]    = df[col].map(encodings[col])
    df_og[col] = df_og[col].map(encodings[col])
    tf[col]    = tf[col].map(encodings[col])
# Out:
# gender target encoding:
# {'Female': 0.4791831466755485, 'Male': 0.4705919751342187}
# ----------------------------------------
# SeniorCitizen target encoding:
# {'No': 0.42147185138329396, 'Yes': 0.7579884525541011}
# ----------------------------------------
# Partner target encoding:
# {'No': 0.5994197180572725, 'Yes': 0.32488054159622676}
# ----------------------------------------
# Dependents target encoding:
# {'No': 0.561053848907327, 'Yes': 0.19798429937433598}
# ----------------------------------------
# PhoneService target encoding:
# {'No': 0.386472834791179, 'Yes': 0.48025534441805223}
# ----------------------------------------
# MultipleLines target encoding:
# {'No': 0.4096786023611295, 'No phone service': 0.386472834791179, 'Yes': 0.5442770082318217}
# ----------------------------------------
# InternetService target encoding:
# {'DSL': 0.264015465341066, 'Fiber optic': 0.6890030226032924, 'No': 0.045005511744255065}
# ----------------------------------------
# OnlineSecurity target encoding:
# {'No': 0.680130062345351, 'No internet service': 0.045005511744255065, 'Yes': 0.22883370860822874}
# ----------------------------------------
# OnlineBackup target encoding:
# {'No': 0.6657835635229091, 'No internet service': 0.045005511744255065, 'Yes': 0.38466764679675663}
# ----------------------------------------
# DeviceProtection target encoding:
# {'No': 0.6561123954205196, 'No internet service': 0.045005511744255065, 'Yes': 0.4099379548723674}
# ----------------------------------------
# TechSupport target encoding:
# {'No': 0.6764482058850659, 'No internet service': 0.045005511744255065, 'Yes': 0.2493158687697937}
# ----------------------------------------
# StreamingTV target encoding:
# {'No': 0.5686794487611269, 'No internet service': 0.045005511744255065, 'Yes': 0.5520877367896311}
# ----------------------------------------
# StreamingMovies target encoding:
# {'No': 0.5709889953977529, 'No internet service': 0.045005511744255065, 'Yes': 0.5500632302296172}
# ----------------------------------------
# Contract target encoding:
# {'Month-to-month': 0.6932515337423313, 'One year': 0.16123676067322448, 'Two year': 0.030759835433273337}
# ----------------------------------------
# PaperlessBilling target encoding:
# {'No': 0.2026789432286124, 'Yes': 0.593067030749616}
# ----------------------------------------
# PaymentMethod target encoding:
# {'Bank transfer (automatic)': 0.2074217907227616, 'Credit card (automatic)': 0.18994882456420917, 'Electronic check': 0.749890751208785, 'Mailed check': 0.21435198852853107}
# ----------------------------------------
# all_binary_same target encoding:
# {False: 0.4762112351586036, True: 0.3720204313280363}
# ----------------------------------------
# all_trinary_same target encoding:
# {False: 0.47608722172593865, True: 0.4655767829420524}
# ----------------------------------------
# all_same_services target encoding:
# {False: 0.475022057896727, True: 0.03225806451612903}
# ----------------------------------------
# dominance_of_nointernetservice target encoding:
# {False: 0.5599575684899917, True: 0.045005511744255065}
# ----------------------------------------
# is_fixed_contract_time target encoding:
# {False: 0.6932515337423313, True: 0.08161964441567866}
# ----------------------------------------
# is_automatic_payment target encoding:
# {False: 0.6157316428948758, True: 0.1983522526822587}
# ----------------------------------------
# rarity_factor target encoding:
# {0.0: 0.6531778902694687, 0.7142857142857143: 0.5369152184566668, 1.4285714285714286: 0.219839994018468, 2.142857142857143: 0.10797655000888257, 2.857142857142857: 0.2318840579710145}
# ----------------------------------------
# categorical_tenure target encoding:
# {'0.0': 0.0, '1.0': 0.8563579622873719, '10.0': 0.7314097042779213, '11.0': 0.6772009029345373, '12.0': 0.6291870055546205, '13.0': 0.6201550387596899, '14.0': 0.6604038137969714, '15.0': 0.6665930181175431, '16.0': 0.672722029988466, '17.0': 0.5940669371196755, '18.0': 0.5155267670032387, '19.0': 0.48048693161475114, '2.0': 0.7702561421850497, '20.0': 0.5117481203007519, '21.0': 0.5465746673238048, '22.0': 0.456436612824278, '23.0': 0.411892901618929, '24.0': 0.4504424778761062, '25.0': 0.46120821833793313, '26.0': 0.48663994655978626, '27.0': 0.3262504086302713, '28.0': 0.5074269286056541, '29.0': 0.47910557184750735, '3.0': 0.7416562250825834, '30.0': 0.5235849056603774, '31.0': 0.49701971572673087, '32.0': 0.49449715370018976, '33.0': 0.39651416122004357, '34.0': 0.40907008703618875, '35.0': 0.33112033195020746, '36.0': 0.5389856169568509, '37.0': 0.4451840250587314, '38.0': 0.24627277747101048, '39.0': 0.31493276716206653, '4.0': 0.7460206646188215, '40.0': 0.4846301633045149, '41.0': 0.39706422018348625, '42.0': 0.3529650690495532, '43.0': 0.31508078994614, '44.0': 0.2286764705882353, '45.0': 0.2550335570469799, '46.0': 0.23056458764410287, '47.0': 0.3258875149581173, '48.0': 0.14918132201334142, '49.0': 0.3846815834767642, '5.0': 0.7544313146233382, '50.0': 0.3053040103492885, '51.0': 0.2082906857727738, '52.0': 0.13721940622737147, '53.0': 0.19957004657828736, '54.0': 0.28383287920072664, '55.0': 0.31717824448034465, '56.0': 0.2866541353383459, '57.0': 0.15110356536502548, '58.0': 0.14866255144032922, '59.0': 0.14394904458598726, '6.0': 0.6987659316204734, '60.0': 0.2108352144469526, '61.0': 0.160650535501785, '62.0': 0.12217391304347826, '63.0': 0.10416666666666667, '64.0': 0.15763765541740674, '65.0': 0.2427253371185238, '66.0': 0.15196078431372548, '67.0': 0.15620351085986314, '68.0': 0.09588159588159588, '69.0': 0.15215453194650816, '7.0': 0.7159076573735335, '70.0': 0.12129032258064516, '71.0': 0.09305536379953058, '72.0': 0.05115346038114343, '8.0': 0.6637055837563451, '9.0': 0.755210173083716}
# ----------------------------------------
# categorical_MonthlyCharges target encoding:
# {'100.0': 0.68, '100.05': 0.6876606683804627, '100.1': 0.6868686868686869, '100.15': 0.7272727272727273, '100.2': 0.7170138888888888, '100.25': 0.6525, '100.3': 0.7021943573667712, '100.35': 0.7746478873239436, '100.4': 0.675603217158177, '100.45': 0.6657303370786517, '100.5': 0.6797829036635007, '100.55': 0.6859504132231405, '100.6': 0.659942363112392, '100.65': 0.6892430278884463, '100.7': 0.625, '100.75': 0.7125, '100.8': 0.6833333333333333, '100.85': 0.7160493827160493, '100.9': 0.6084656084656085, '100.95': 0.6376811594202898, '101.0': 0.7549019607843137, '101.05': 0.7100591715976331, '101.1': 0.7544483985765125, '101.15': 0.796976241900648, '101.2': 0.8095238095238095, '101.25': 0.7508896797153025, '101.3': 0.7293577981651376, '101.35': 0.7533875338753387, '101.4': 0.7913669064748201, '101.45': 0.7387387387387387, '101.5': 0.7802197802197802, '101.55': 0.7804878048780488, '101.6': 0.6666666666666666, '101.65': 0.6923076923076923, '101.7': 0.7794117647058824, '101.75': 0.8135593220338984, '101.8': 0.7083333333333334, '101.85': 0.7948717948717948, '101.9': 0.8024691358024691, '101.95': 0.8181818181818182, '102.0': 0.6521739130434783, '102.05': 0.6190476190476191, '102.1': 0.7769230769230769, '102.15': 0.7049180327868853, '102.2': 0.7692307692307693, '102.25': 0.7291666666666666, '102.3': 0.7647058823529411, '102.35': 0.7755102040816326, '102.4': 0.765625, '102.45': 0.8, '102.5': 0.6567164179104478, '102.55': 1.0, '102.6': 0.6739130434782609, '102.65': 0.4473684210526316, '102.7': 0.6363636363636364, '102.75': 0.7073170731707317, '102.8': 0.7272727272727273, '102.85': 0.775, '102.9': 0.7818181818181819, '102.95': 0.6666666666666666, '103.0': 0.3194444444444444, '103.05': 0.5576923076923077, '103.1': 0.53, '103.15': 0.48623853211009177, '103.2': 0.5, '103.25': 0.5384615384615384, '103.3': 0.5666666666666667, '103.35': 0.5, '103.4': 0.6086956521739131, '103.45': 0.5277777777777778, '103.5': 0.45714285714285713, '103.55': 0.48148148148148145, '103.6': 0.4722222222222222, '103.65': 0.46258503401360546, '103.7': 0.49586776859504134, '103.75': 0.5338983050847458, '103.8': 0.5178571428571429, '103.85': 0.6118421052631579, '103.9': 0.4666666666666667, '103.95': 0.5690866510538641, '104.0': 0.532258064516129, '104.05': 0.6018662519440124, '104.1': 0.5135135135135135, '104.15': 0.60546875, '104.2': 0.6132075471698113, '104.25': 0.5146198830409356, '104.3': 0.6020408163265306, '104.35': 0.6118143459915611, '104.4': 0.5834482758620689, '104.45': 0.603448275862069, '104.5': 0.5609756097560976, '104.55': 0.671875, '104.6': 0.5145631067961165, '104.65': 0.5669291338582677, '104.7': 0.5925925925925926, '104.75': 0.5802469135802469, '104.8': 0.5846994535519126, '104.85': 0.63125, '104.9': 0.599388379204893, '104.95': 0.5993031358885017, '105.0': 0.5007776049766719, '105.05': 0.5416666666666666, '105.1': 0.5382716049382716, '105.15': 0.5886524822695035, '105.2': 0.52734375, '105.25': 0.5088495575221239, '105.3': 0.583732057416268, '105.35': 0.5582191780821918, '105.4': 0.5208333333333334, '105.45': 0.47692307692307695, '105.5': 0.545751633986928, '105.55': 0.57, '105.6': 0.47101449275362317, '105.65': 0.49264705882352944, '105.7': 0.43636363636363634, '105.75': 0.5132743362831859, '105.8': 0.524390243902439, '105.85': 0.5764705882352941, '105.9': 0.4371584699453552, '105.95': 0.5882352941176471, '106.0': 0.6055045871559633, '106.05': 0.5338078291814946, '106.1': 0.5802816901408451, '106.15': 0.4830508474576271, '106.2': 0.5087719298245614, '106.25': 0.5308641975308642, '106.3': 0.6727272727272727, '106.35': 0.5416666666666666, '106.4': 0.5840336134453782, '106.45': 0.5545454545454546, '106.5': 0.5793650793650794, '106.55': 0.5531914893617021, '106.6': 0.5625, '106.65': 0.4782608695652174, '106.7': 0.40229885057471265, '106.75': 0.5564516129032258, '106.8': 0.48, '106.85': 0.65, '106.9': 0.47560975609756095, '106.95': 0.4838709677419355, '107.0': 0.16666666666666666, '107.05': 0.47058823529411764, '107.1': 0.2903225806451613, '107.15': 0.3636 ...
# ----------------------------------------
# categorical_TotalCharges target encoding:
# {'0.0': 0.0, '100.0': 1.0, '100.05': 0.9166666666666666, '100.1': 0.8571428571428571, '100.15': 0.8235294117647058, '100.2': 0.8055555555555556, '100.25': 0.9285714285714286, '100.3': 0.9285714285714286, '100.35': 0.8, '100.4': 0.8125, '100.45': 1.0, '100.5': 0.7567567567567568, '100.55': 0.9459459459459459, '100.6': 0.9, '100.65': 1.0, '100.7': 0.5714285714285714, '100.75': 0.9375, '100.8': 0.9090909090909091, '100.85': 0.9, '100.9': 0.6, '1001.2': 0.8333333333333334, '1001.5': 0.13333333333333333, '1002.5': 0.0, '1002.7': 0.0, '1003.05': 0.1111111111111111, '1003.25': 0.3333333333333333, '1003.5': 0.0, '1004.05': 0.0, '1004.15': 0.0, '1004.25': 0.0, '1004.35': 0.125, '1004.5': 0.041666666666666664, '1004.75': 0.6875, '1004.85': 0.6, '1005.2': 0.5, '1005.5': 0.0, '1005.7': 0.0, '1006.7': 0.0, '1006.9': 0.0625, '1007.7': 1.0, '1007.8': 0.7142857142857143, '1007.9': 0.17647058823529413, '1008.0': 0.0, '1008.55': 1.0, '1008.6': 1.0, '1008.7': 0.6666666666666666, '1008.75': 1.0, '1008.8': 0.0, '1008.85': 1.0, '1009.25': 1.0, '1009.5': 0.0, '1009.9': 1.0, '101.0': 1.0, '101.05': 0.6666666666666666, '101.1': 0.9, '101.15': 1.0, '101.2': 1.0, '101.25': 1.0, '101.3': 1.0, '101.35': 0.75, '101.4': 1.0, '101.45': 1.0, '101.5': 0.8333333333333334, '101.55': 1.0, '101.6': 1.0, '101.65': 0.75, '101.7': 0.6, '101.75': 1.0, '101.8': 0.0, '101.85': 0.0, '101.9': 0.9230769230769231, '1010.0': 1.0, '1011.05': 0.5384615384615384, '1011.2': 0.5, '1011.4': 0.0, '1011.5': 0.2727272727272727, '1011.6': 1.0, '1011.7': 0.3333333333333333, '1011.8': 1.0, '1012.4': 0.0, '1012.7': 0.0, '1013.05': 0.06521739130434782, '1013.25': 0.0, '1013.35': 0.3333333333333333, '1013.4': 0.0, '1014.15': 0.0, '1014.2': 0.0, '1014.25': 0.14285714285714285, '1014.35': 0.0, '1014.7': 0.0, '1016.7': 0.16666666666666666, '1017.2': 0.0, '1017.35': 0.375, '1018.7': 0.0, '102.0': 1.0, '102.1': 0.5, '102.3': 1.0, '102.35': 0.5, '102.4': 1.0, '102.45': 1.0, '102.5': 0.8461538461538461, '102.55': 1.0, '102.7': 0.7, '102.75': 0.8, '102.8': 1.0, '102.85': 0.3333333333333333, '102.9': 1.0, '1020.1': 0.4444444444444444, '1020.2': 0.8125, '1020.25': 0.0, '1020.3': 0.5, '1020.4': 0.7692307692307693, '1020.45': 0.5, '1020.5': 0.35714285714285715, '1020.55': 0.8888888888888888, '1020.6': 0.5952380952380952, '1020.65': 0.625, '1020.7': 0.5555555555555556, '1020.75': 0.5517241379310345, '1020.8': 0.6666666666666666, '1020.85': 0.5, '1020.9': 0.6, '1020.95': 0.5, '1021.2': 0.0, '1021.3': 0.7333333333333333, '1021.4': 0.7647058823529411, '1021.5': 0.5714285714285714, '1021.55': 0.75, '1021.6': 0.5, '1021.65': 1.0, '1021.7': 0.42857142857142855, '1021.75': 0.6071428571428571, '1021.8': 0.10344827586206896, '1021.9': 0.5, '1021.95': 0.0, '1022.05': 0.6666666666666666, '1022.1': 1.0, '1022.4': 0.5, '1022.5': 0.24390243902439024, '1022.55': 0.5, '1022.6': 0.09090909090909091, '1022.65': 0.25, '1022.7': 0.5, '1022.75': 0.16666666666666666, '1022.8': 0.0, '1022.85': 0.2, '1022.9': 0.6, '1022.95': 0.21428571428571427, '1023.05': 0.5, '1023.1': 0.5, '1023.15': 0.0, '1023.2': 1.0, '1023.25': 1.0, '1023.3': 0.3333333333333333, '1023.35': 0.5, '1023.4': 0.5714285714285714, '1023.45': 0.4, '1023.5': 0.6666666666666666, '1023.55': 1.0, '1023.6': 1.0, '1023.7': 0.0, '1023.75': 0.5454545454545454, '1023.8': 0.5, '1023.85': 0.5230769230769231, '1023.9': 0.5666666666666667, '1023.95': 0.4519230769230769, '1024.0': 0.0, '1024.25': 0.0, '1024.6': 0.0, '1024.65': 0.0, '1024.7': 0.0, '1024.8': 0.0, '1025.05': 0.0, '1025.1': 0.0, '1025.15': 0.29069767441860467, '1025.25': 0.0, '1025.35': 0.25, '1025.5': 0.45454545454545453, '1025.55': 0.0, '1025.6': 0.2727272727272727, '1025.65': 0.5, '1025.7': 0.0, '1025.75': 0.5, '1025.8': 0.5, '1025.85': 0.0, '1025.9': 0.5, '1025.95': 0.4166666666666667, '1026.0': 0.0, '1026.05': 0.0, '1026.1': 0.0, '1026.15': 0.08, '1026.25': 0.07692307692307693, '1026.35': 0.0, '1026.45': 0.0, '1026.55': 0.0, '1026.85': 0.0, '1027.05': 1.0, '1027.15': 0.0, '1027.25': 0.5, '1027.35': 0.0, '10 ...
# ----------------------------------------

# %%
# # correlations
# spearman_corr = df_og.corr(method="spearman")
# kendall_corr  = df_og.corr(method="pearson")

# # one row, two columns
# fig, axes = plt.subplots(1, 2, figsize=(22, 10))

# # Spearman
# sns.heatmap(
#     spearman_corr.round(2),
#     annot=True,
#     fmt=".2f",
#     cmap="coolwarm",
#     center=0,
#     ax=axes[0]
# )
# axes[0].set_title("Spearman Correlation (Monotonic Relationships) -- Before")

# # Pearson
# sns.heatmap(
#     kendall_corr.round(2),
#     annot=True,
#     fmt=".2f",
#     cmap="coolwarm",
#     center=0,
#     ax=axes[1],
#     yticklabels=False
# )
# axes[1].set_title("Pearson Correlation (Linear Relationships) -- Before")

# plt.tight_layout()
# # correlations
# spearman_corr = df.corr(method="spearman")
# kendall_corr  = df.corr(method="pearson")

# # one row, two columns
# fig, axes = plt.subplots(1, 2, figsize=(22, 10))

# # Spearman
# sns.heatmap(
#     spearman_corr.round(2),
#     annot=True,
#     fmt=".2f",
#     cmap="coolwarm",
#     center=0,
#     ax=axes[0]
# )
# axes[0].set_title("Spearman Correlation (Monotonic Relationships) -- After")

# # Pearson
# sns.heatmap(
#     kendall_corr.round(2),
#     annot=True,
#     fmt=".2f",
#     cmap="coolwarm",
#     center=0,
#     ax=axes[1],
#     yticklabels=False
# )
# axes[1].set_title("Pearson Correlation (Linear Relationships) -- After")

# plt.tight_layout()
# plt.show()

# %%
df.columns
# Out:
# Index(['gender', 'SeniorCitizen', 'Partner', 'Dependents', 'tenure',
#        'PhoneService', 'MultipleLines', 'InternetService', 'OnlineSecurity',
#        'OnlineBackup', 'DeviceProtection', 'TechSupport', 'StreamingTV',
#        'StreamingMovies', 'Contract', 'PaperlessBilling', 'PaymentMethod',
#        'MonthlyCharges', 'TotalCharges', 'Churn', 'is_auto_payment',
#        'paperless_autopay', 'high_monthlycharges', 'high_totalcharges',
#        'high_tenure', 'is_male_senior', 'feat_streaming_internet_phone',
#        'feat_support_bundle', 'tenure_TotalCharges_ratio',
#        'tenure_MonthlyCharges_ratio', 'TotalCharges_tenure_ratio',
#        'TotalCharges_MonthlyCharges_ratio', 'MonthlyCharges_tenure_ratio',
#        'MonthlyCharges_TotalCharges_ratio', 'all_binary_same',
#        'all_trinary_same', 'all_same_services', 'categorical_tenure',
#        'categorical_TotalCharges', 'categorical_MonthlyCharges',
#        'dominance_of_nointernetservice', 'is_fixed_contract_time',
#        'is_automatic_payment', 'rarity_factor'],
#       dtype='object')

# %%
scaler = MinMaxScaler()
scale_cols = ['tenure',
       'MonthlyCharges', 'TotalCharges', 'tenure_TotalCharges_ratio',
       'tenure_MonthlyCharges_ratio', 'TotalCharges_tenure_ratio',
       'TotalCharges_MonthlyCharges_ratio', 'MonthlyCharges_tenure_ratio',
       'MonthlyCharges_TotalCharges_ratio', ]


df[scale_cols] = df[scale_cols].apply(pd.to_numeric, errors='coerce')
tf[scale_cols] = tf[scale_cols].apply(pd.to_numeric, errors='coerce')

# %%
df.Churn.value_counts()
# Out:
# Churn
# 0    150000
# 1    135674
# Name: count, dtype: int64

# %%
X_train.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 228539 entries, 0 to 285673
# Data columns (total 43 columns):
#  #   Column                             Non-Null Count   Dtype
# ---  ------                             --------------   -----
#  0   gender                             228539 non-null  float64
#  1   SeniorCitizen                      228539 non-null  float64
#  2   Partner                            228539 non-null  float64
#  3   Dependents                         228539 non-null  float64
#  4   tenure                             228539 non-null  float64
#  5   PhoneService                       228539 non-null  float64
#  6   MultipleLines                      228539 non-null  float64
#  7   InternetService                    228539 non-null  float64
#  8   OnlineSecurity                     228539 non-null  float64
#  9   OnlineBackup                       228539 non-null  float64
#  10  DeviceProtection                   228539 non-null  float64
#  11  TechSupport                        228539 non-null  float64
#  12  StreamingTV                        228539 non-null  float64
#  13  StreamingMovies                    228539 non-null  float64
#  14  Contract                           228539 non-null  float64
#  15  PaperlessBilling                   228539 non-null  float64
#  16  PaymentMethod                      228539 non-null  float64
#  17  MonthlyCharges                     228539 non-null  float64
#  18  TotalCharges                       228539 non-null  float64
#  19  is_auto_payment                    228539 non-null  int64
#  20  paperless_autopay                  228539 non-null  int64
#  21  high_monthlycharges                228539 non-null  int64
#  22  high_totalcharges                  228539 non-null  int64
#  23  high_tenure                        228539 non-null  int64
#  24  is_male_senior                     228539 non-null  int64
#  25  feat_streaming_internet_phone      228539 non-null  int64
#  26  feat_support_bundle                228539 non-null  int64
#  27  tenure_TotalCharges_ratio          228537 non-null  float64
#  28  tenure_MonthlyCharges_ratio        228539 non-null  float64
#  29  TotalCharges_tenure_ratio          228537 non-null  float64
#  30  TotalCharges_MonthlyCharges_ratio  228539 non-null  float64
#  31  MonthlyCharges_tenure_ratio        228539 non-null  float64
#  32  MonthlyCharges_TotalCharges_ratio  228539 non-null  float64
#  33  all_binary_same                    228539 non-null  float64
#  34  all_trinary_same                   228539 non-null  float64
#  35  all_same_services                  228539 non-null  float64
#  36  categorical_tenure                 228539 non-null  float64
#  37  categorical_TotalCharges           228539 non-null  float64
#  38  categorical_MonthlyCharges         228539 non-null  float64
#  39  dominance_of_nointernetservice     228539 non-null  float64
#  40  is_fixed_contract_time             228539 non-null  float64
#  41  is_automatic_payment               228539 non-null  float64
#  42  rarity_factor                      228539 non-null  float64
# dtypes: float64(35), int64(8)
# memory usage: 76.7 MB

# %%
target_col = 'Churn'

X = df.drop(columns=[target_col])
y = df[target_col]

X_train, X_test, y_train, y_test = train_test_split(
    X, y,
    test_size=0.15,
    random_state=42,
    stratify=y
)
X_train = X_train.clip(-1e6, 1e6)
X_test  = X_test.clip(-1e6, 1e6)


print(X_train.isnull().sum().sum(), X_test.isnull().sum().sum())
X_train.fillna(-1, inplace=True)
print(X_train.isnull().sum().sum(), X_test.isnull().sum().sum())
# Out:
# 6 0
# 0 0

# %%
skf = StratifiedKFold(n_splits=5, shuffle=True, random_state=42)

fold_results = []

# %% [markdown]
# ## CatBoost

# %%
for fold, (train_idx, test_idx) in enumerate(skf.split(X, y), 1):
    X_train, X_test = X.iloc[train_idx], X.iloc[test_idx]
    y_train, y_test = y.iloc[train_idx], y.iloc[test_idx]
    
    cat = CatBoostClassifier(
        iterations=110,
        learning_rate=0.3,
        depth=8,
        eval_metric="AUC",
        verbose=0,
        random_state=42
    )
    
    cat.fit(X_train, y_train)
    
    test_probs = cat.predict_proba(X_test)[:, 1]
    
    # default threshold 0.5
    test_preds = (test_probs >= 0.5).astype(int)
    
    metrics = {
        "fold": fold,
        "test_acc": accuracy_score(y_test, test_preds),
        "test_f1": f1_score(y_test, test_preds),
        "test_roc": roc_auc_score(y_test, test_probs)
    }
    
    fold_results.append(metrics)
fold_df = pd.DataFrame(fold_results)
print(fold_df)
print("\nMean metrics across folds:")
print(fold_df.mean())
# Out:
#    fold  test_acc   test_f1  test_roc
# 0     1  0.852682  0.850218  0.930075
# 1     2  0.850074  0.847575  0.928976
# 2     3  0.848587  0.845834  0.928477
# 3     4  0.852927  0.849896  0.931512
# 4     5  0.853642  0.851099  0.930972
#
# Mean metrics across folds:
# fold        3.000000
# test_acc    0.851583
# test_f1     0.848924
# test_roc    0.930002
# dtype: float64

# %%
# model
cat = CatBoostClassifier(
    iterations=110,
    learning_rate=0.3,
    depth=8,
    eval_metric="AUC",
    verbose=0,
    random_state=42
)

cat.fit(X_train, y_train)

# probabilities (MANDATORY for ROC)
train_probs = cat.predict_proba(X_train)[:, 1]
test_probs  = cat.predict_proba(X_test)[:, 1]

thresholds = np.arange(0.0, 1.01, 0.05)
rows = []

for t in thresholds:
    train_preds = (train_probs >= t).astype(int)
    test_preds  = (test_probs  >= t).astype(int)

    row = {
        "threshold": round(t, 2),
        "train_acc": accuracy_score(y_train, train_preds),
        "test_acc": accuracy_score(y_test, test_preds),
        "train_f1": f1_score(y_train, train_preds),
        "test_f1": f1_score(y_test, test_preds),

        # FIX: use probabilities
        "train_roc": roc_auc_score(y_train, train_probs),
        "test_roc": roc_auc_score(y_test, test_probs)
    }

    rows.append(row)

thresh_df = pd.DataFrame(rows)
print(thresh_df)
# Out:
#     threshold  train_acc  test_acc  train_f1   test_f1  train_roc  test_roc
# 0        0.00   0.474928  0.474919  0.644001  0.643993   0.939417  0.930972
# 1        0.05   0.741498  0.741870  0.785276  0.785202   0.939417  0.930972
# 2        0.10   0.784467  0.781654  0.813330  0.810804   0.939417  0.930972
# 3        0.15   0.809329  0.803795  0.830252  0.825411   0.939417  0.930972
# 4        0.20   0.825125  0.819880  0.841044  0.836185   0.939417  0.930972
# 5        0.25   0.836720  0.830941  0.848814  0.843348   0.939417  0.930972
# 6        0.30   0.846723  0.838292  0.855464  0.847564   0.939417  0.930972
# 7        0.35   0.854323  0.845241  0.860134  0.851505   0.939417  0.930972
# 8        0.40   0.859005  0.849039  0.862099  0.852667   0.939417  0.930972
# 9        0.45   0.862772  0.852242  0.863160  0.852747   0.939417  0.930972
# 10       0.50   0.863858  0.853642  0.861464  0.851099   0.939417  0.930972
# 11       0.55   0.862982  0.852505  0.857372  0.846567   0.939417  0.930972
# 12       0.60   0.859574  0.848602  0.850137  0.838547   0.939417  0.930972
# 13       0.65   0.852372  0.841390  0.837807  0.825851   0.939417  0.930972
# 14       0.70   0.840409  0.829874  0.818315  0.806382   0.939417  0.930972
# 15       0.75   0.822858  0.814541  0.789207  0.779333   0.939417  0.930972
# 16       0.80   0.797283  0.789635  0.745222  0.735422   0.939417  0.930972
# 17       0.85   0.759574  0.752932  0.674776  0.665498   0.939417  0.930972
# 18       0.90   0.704446  0.700179  0.558153  0.550771   0.939417  0.930972
# 19       0.95   0.629163  0.628120  0.363296  0.361165   0.939417  0.930972
# 20       1.00   0.525072  0.525081  0.000000  0.000000   0.939417  0.930972

# %% [markdown]
# ## XGBoost

# %%
# for fold, (train_idx, test_idx) in enumerate(skf.split(X, y), 1):
#     X_train, X_test = X.iloc[train_idx], X.iloc[test_idx]
#     y_train, y_test = y.iloc[train_idx], y.iloc[test_idx]


#     xgb = XGBClassifier(
#     n_estimators=200,
#     learning_rate=0.06,
#     max_depth=7,
#     random_state=42,
#     objective="binary:logistic",
#     eval_metric="auc",
# )

    
#     xgb.fit(X_train, y_train)
    
#     test_probs = xgb.predict_proba(X_test)[:, 1]
    
#     # default threshold 0.5
#     test_preds = (test_probs >= 0.5).astype(int)
    
#     metrics = {
#         "fold": fold,
#         "test_acc": accuracy_score(y_test, test_preds),
#         "test_f1": f1_score(y_test, test_preds),
#         "test_roc": roc_auc_score(y_test, test_probs)
#     }
    
#     fold_results.append(metrics)
# fold_df = pd.DataFrame(fold_results)
# print(fold_df)
# print("\nMean metrics across folds:")
# print(fold_df.mean())

# %%
# xgb = XGBClassifier(
#     n_estimators=200,
#     learning_rate=0.06,
#     max_depth=7,
#     random_state=42,
#     objective="binary:logistic",
#     eval_metric="auc",
# )

# xgb.fit(X_train, y_train)

# # probabilities
# train_probs = xgb.predict_proba(X_train)[:, 1]
# test_probs  = xgb.predict_proba(X_test)[:, 1]

# thresholds = np.arange(0.0, 1.01, 0.05)
# rows = []

# for t in thresholds:
#     train_preds = (train_probs >= t).astype(int)
#     test_preds  = (test_probs  >= t).astype(int)

#     row = {
#         "threshold": round(t, 2),
#         "train_acc": accuracy_score(y_train, train_preds),
#         "test_acc": accuracy_score(y_test, test_preds),
#         "train_f1": f1_score(y_train, train_preds),
#         "test_f1": f1_score(y_test, test_preds),
#         "train_roc": roc_auc_score(y_train, train_probs),
#         "test_roc": roc_auc_score(y_test, test_probs)
#     }

#     rows.append(row)

# thresh_df = pd.DataFrame(rows)
# print(thresh_df)

# %% [markdown]
# ## LGBM

# %%
for fold, (train_idx, test_idx) in enumerate(skf.split(X, y), 1):
    X_train, X_test = X.iloc[train_idx], X.iloc[test_idx]
    y_train, y_test = y.iloc[train_idx], y.iloc[test_idx]
    
    model = lgb.LGBMClassifier(
        n_estimators=200,
        learning_rate=0.10,
        max_depth=14,
        random_state=42
    )
    
    model.fit(X_train, y_train)
    
    test_probs = model.predict_proba(X_test)[:, 1]
    
    # default threshold 0.5
    test_preds = (test_probs >= 0.5).astype(int)
    
    metrics = {
        "fold": fold,
        "test_acc": accuracy_score(y_test, test_preds),
        "test_f1": f1_score(y_test, test_preds),
        "test_roc": roc_auc_score(y_test, test_probs)
    }
    
    fold_results.append(metrics)
fold_df = pd.DataFrame(fold_results)
print(fold_df)
print("\nMean metrics across folds:")
print(fold_df.mean())
# Out:
# [LightGBM] [Info] Number of positive: 108539, number of negative: 120000
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.038877 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 2795
# [LightGBM] [Info] Number of data points in the train set: 228539, number of used features: 43
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.474926 -> initscore=-0.100382
# [LightGBM] [Info] Start training from score -0.100382
# [LightGBM] [Info] Number of positive: 108539, number of negative: 120000
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.039014 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 2795
# [LightGBM] [Info] Number of data points in the train set: 228539, number of used features: 43
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.474926 -> initscore=-0.100382
# [LightGBM] [Info] Start training from score -0.100382
# [LightGBM] [Info] Number of positive: 108539, number of negative: 120000
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.039514 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 2795
# [LightGBM] [Info] Number of data points in the train set: 228539, number of used features: 43
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.474926 -> initscore=-0.100382
# [LightGBM] [Info] Start training from score -0.100382
# [LightGBM] [Info] Number of positive: 108539, number of negative: 120000
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.045757 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 2795
# [LightGBM] [Info] Number of data points in the train set: 228539, number of used features: 43
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.474926 -> initscore=-0.100382
# [LightGBM] [Info] Start training from score -0.100382
# [LightGBM] [Info] Number of positive: 108540, number of negative: 120000
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.041579 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 2795
# [LightGBM] [Info] Number of data points in the train set: 228540, number of used features: 43
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.474928 -> initscore=-0.100373
# [LightGBM] [Info] Start training from score -0.100373
#    fold  test_acc   test_f1  test_roc
# 0     1  0.852682  0.850218  0.930075
# 1     2  0.850074  0.847575  0.928976
# 2     3  0.848587  0.845834  0.928477
# 3     4  0.852927  0.849896  0.931512
# 4     5  0.853642  0.851099  0.930972
# 5     1  0.852280  0.850073  0.930523
# 6     2  0.851755  0.849310  0.930262
# 7     3  0.849689  0.846954  0.929286
# 8     4  0.853050  0.850264  0.932163
# 9     5  0.854780  0.852306  0.931589
#
# Mean metrics across folds:
# fold        3.000000
# test_acc    0.851947
# test_f1     0.849353
# test_roc    0.930384
# dtype: float64

# %%
# model
lgbm = lgb.LGBMClassifier(
    n_estimators=200,
    learning_rate=0.10,
    max_depth=14,
    random_state=42
)

lgbm.fit(X_train, y_train)

# probabilities
train_probs = lgbm.predict_proba(X_train)[:, 1]
test_probs  = lgbm.predict_proba(X_test)[:, 1]

# thresholds
thresholds = np.arange(0.0, 1.01, 0.05)
rows = []

for t in thresholds:
    train_preds = (train_probs >= t).astype(int)
    test_preds  = (test_probs  >= t).astype(int)

    row = {
        "threshold": round(t, 2),
        "train_acc": accuracy_score(y_train, train_preds),
        "test_acc": accuracy_score(y_test, test_preds),
        "train_f1": f1_score(y_train, train_preds),
        "test_f1": f1_score(y_test, test_preds),
        "train_roc": roc_auc_score(y_train, train_probs),
        "test_roc": roc_auc_score(y_test, test_probs)
    }

    rows.append(row)

thresh_df = pd.DataFrame(rows)
print(thresh_df)
# Out:
# [LightGBM] [Info] Number of positive: 108540, number of negative: 120000
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.038608 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 2795
# [LightGBM] [Info] Number of data points in the train set: 228540, number of used features: 43
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.474928 -> initscore=-0.100373
# [LightGBM] [Info] Start training from score -0.100373
#     threshold  train_acc  test_acc  train_f1   test_f1  train_roc  test_roc
# 0        0.00   0.474928  0.474919  0.644001  0.643993   0.937084  0.931589
# 1        0.05   0.737770  0.735972  0.783106  0.781456   0.937084  0.931589
# 2        0.10   0.783556  0.779413  0.812890  0.809245   0.937084  0.931589
# 3        0.15   0.808340  0.803427  0.829570  0.825196   0.937084  0.931589
# 4        0.20   0.823099  0.819425  0.839450  0.835965   0.937084  0.931589
# 5        0.25   0.833933  0.830206  0.846505  0.842840   0.937084  0.931589
# 6        0.30   0.843043  0.838730  0.852270  0.848014   0.937084  0.931589
# 7        0.35   0.849453  0.845696  0.855736  0.852026   0.937084  0.931589
# 8        0.40   0.853969  0.850807  0.857442  0.854316   0.937084  0.931589
# 9        0.45   0.856874  0.853940  0.857469  0.854477   0.937084  0.931589
# 10       0.50   0.858191  0.854780  0.855731  0.852306   0.937084  0.931589
# 11       0.55   0.857732  0.853712  0.851893  0.847876   0.937084  0.931589
# 12       0.60   0.854117  0.849424  0.844109  0.839253   0.937084  0.931589
# 13       0.65   0.847046  0.841355  0.831604  0.825504   0.937084  0.931589
# 14       0.70   0.835569  0.830504  0.812382  0.806645   0.937084  0.931589
# 15       0.75   0.819021  0.813141  0.784202  0.777119   0.937084  0.931589
# 16       0.80   0.793598  0.788952  0.739693  0.733901   0.937084  0.931589
# 17       0.85   0.756804  0.752022  0.669764  0.663564   0.937084  0.931589
# 18       0.90   0.702468  0.699986  0.553549  0.550117   0.937084  0.931589
# 19       0.95   0.624871  0.622694  0.350279  0.344792   0.937084  0.931589
# 20       1.00   0.525072  0.525081  0.000000  0.000000   0.937084  0.931589

# %%
# xgb_preds = xgb.predict(X_test)
cat_preds = cat.predict(X_test)
lgb_preds = lgbm.predict(X_test)
stack = np.vstack([ cat_preds, lgb_preds])

# majority vote
final_preds = np.round(stack.mean(axis=0)).astype(int)

# probabilities (average for ROC)
# xgb_prob = xgb.predict_proba(X_test)[:, 1]
cat_prob = cat.predict_proba(X_test)[:, 1]
lgb_prob = lgbm.predict_proba(X_test)[:, 1]

avg_prob = ( (.48*cat_prob)+ (.52*lgb_prob)) 

metrics = {
    "Accuracy": accuracy_score(y_test, final_preds),
    "F1": f1_score(y_test, final_preds),
    "ROC-AUC": roc_auc_score(y_test, avg_prob)
}

print(metrics)
# Out:
# {'Accuracy': 0.8540448769559281, 'F1': 0.8496854552337004, 'ROC-AUC': np.float64(0.9318758513304342)}

# %%
tf_id = tf.pop('id')

# %%
# predictions (test file tf)
# xgb_preds = xgb.predict(tf)
cat_preds = cat.predict(tf)
lgb_preds = lgbm.predict(tf)

# stack
stack = np.vstack([cat_preds, lgb_preds])

# hard voting
final_preds = np.round(stack.mean(axis=0)).astype(int)

# probabilities (for submission)

cat_prob = cat.predict_proba(tf)[:, 1]
lgb_prob = lgbm.predict_proba(tf)[:, 1]

avg_prob = ( (.48*cat_prob)+ (.52*lgb_prob))

# %%
submission_ensemble = pd.DataFrame({
    "id": tf_id,
    "Churn": avg_prob   
})

submission_ensemble.to_csv("ensemble_churn_predictions_updated_FE.csv", index=False)
